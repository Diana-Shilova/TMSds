# %% [markdown]
# Найти определитель матриц, первоначально решив самостоятельно на листике

# %%
import numpy as np

# %%
A = np.array([
    [4, 0, 4, 5],
    [0, 1, 5, 6],
    [-2, 2, 2, 0],
    [1, -5, 1, 3]
])

# %%
det = round(np.linalg.det(A)) # good job
print(f'determinant - {det}')
# Out:
# determinant - 188

# %%
A_2 = np.array([
    [5, 0, 1, 3],
    [0, 1, 5, -1],
    [7, -1, 3, -2],
    [5, 3, 0, 1]
])

# %%
det = round(np.linalg.det(A_2)) # good job
print(f'determinant - {det}')
# Out:
# determinant - -543

# %%
A_3 = np.array([
    [4, 0, 1, 5],
    [1, 1, 0, 4],
    [0, 1, 1, 5],
    [6, -4, 1, 1]
])

# %%
det = round(np.linalg.det(A_3)) # good job
print(f'determinant  {det}')
# Out:
# determinant  36

# %%
A_4 = np.array([
    [5, 1, 3, 0],
    [-3, 0, 5, 2],
    [2, 1, -1, 3],
    [1, 5, 0, 7]
])

# %%
det = round(np.linalg.det(A_4)) # good job
print(f'determinant - {det}')
# Out:
# determinant - 408

# %%
A_5 = np.array([
    [7, 6, 0, 1],
    [1, 3, 5, 0],
    [0, 1, -2, 4],
    [1, 1, 2, 3]
])

# %%
det = round(np.linalg.det(A_5))
print(f'determinant - {det}')
# Out:
# determinant - -288

# %%
A_6 = np.array([
    [2, 3, 0, 1],
    [-4, 0, 3, 1],
    [0, 8, 7, 5],
    [3, 3, 4, 5]
])

# %%
det = round(np.linalg.det(A_6))
print(f'determinant - {det}')
# Out:
# determinant - 96

# %%
A_7 = np.array([
    [3, 1, 3, 1],
    [2, 4, 2, 5],
    [1, 4, 5, 3],
    [-1, 0, 3, 2]
])

# %%
det = round(np.linalg.det(A_7)) # good job
print(f'determinant - {det}')
# Out:
# determinant - 160

# %%
A_8 = np.array([
    [7, 6, 0, 1],
    [1, 3, 5, 0],
    [0, 1, -2, 4],
    [1, 1, 2, 3]
])

# %%
det = round(np.linalg.det(A_8)) # good job
print(f'determinant - {det}')
# Out:
# determinant - -288

# %% [markdown]
# Операции сложения, вычитания, умножения матриц, первоначально решив на листике (все задачи с данными действиями были решены верно)

# %%
AM = np.array([
    [1, 2, 4],
    [7, 5, -2],
    [-2, 1, 3]
])

BM = np.array([
    [-1, 0, 3],
    [2, -6, 1],
    [7, 1, 5]
])

CM = np.array([
    [-2, 3],
    [4, 0],
    [7, -1]
])

# %%
summ = np.add(AM, BM)
subst = np.subtract(AM, BM)
mult = np.dot(AM, BM)
mult_new = np.dot(mult, CM)

print( f'sum \n {summ}')
print(f'subtract \n {subst}')
print(f'multiply 2 matrix \n {mult}')
print(f'multiply 3 matrix \n {mult_new}')
# Out:
# sum
#  [[ 0  2  7]
#  [ 9 -1 -1]
#  [ 5  2  8]]
# subtract
#  [[ 2  2  1]
#  [ 5 11 -3]
#  [-9  0 -2]]
# multiply 2 matrix
#  [[ 31  -8  25]
#  [-11 -32  16]
#  [ 25  -3  10]]
# multiply 3 matrix
#  [[ 81  68]
#  [  6 -49]
#  [  8  65]]

# %%
AM = np.array([
    [0, 3, 4],
    [-7, 1, -2],
    [2, -1, 3]
])

BM = np.array([
    [1, 2, 4],
    [7, 0, -2],
    [-3, -2, 5]
])

CM = np.array([
    [-3, 2],
    [0, 4],
    [-1, 7]
])

# %%
summ = np.add(AM, BM)
subst = np.subtract(AM, BM)
mult = np.dot(AM, BM)
mult_new = np.dot(mult, CM)

print( f'sum \n {summ}')
print(f'subtract \n {subst}')
print(f'multiply 2 matrix \n {mult}')
print(f'multiply 3 matrix \n {mult_new}')
# Out:
# sum
#  [[ 1  5  8]
#  [ 0  1 -4]
#  [-1 -3  8]]
# subtract
#  [[ -1   1   0]
#  [-14   1   0]
#  [  5   1  -2]]
# multiply 2 matrix
#  [[  9  -8  14]
#  [  6 -10 -40]
#  [-14  -2  25]]
# multiply 3 matrix
#  [[ -41   84]
#  [  22 -308]
#  [  17  139]]

# %%
AM = np.array([
    [5, 2, 9],
    [7, 0, -2],
    [-2, 1, 6]
])

BM = np.array([
    [1, -2, 1],
    [7, 5, -2],
    [-2, 8, 3]
])

CM = np.array([
    [-2, 3],
    [4, 5],
    [0, -1]
])

# %%
summ = np.add(AM, BM)
subst = np.subtract(AM, BM)
mult = np.dot(AM, BM)
mult_new = np.dot(mult, CM)

print( f'sum \n {summ}')
print(f'subtract \n {subst}')
print(f'multiply 2 matrix \n {mult}')
print(f'multiply 3 matrix \n {mult_new}')
# Out:
# sum
#  [[ 6  0 10]
#  [14  5 -4]
#  [-4  9  9]]
# subtract
#  [[ 4  4  8]
#  [ 0 -5  0]
#  [ 0 -7  3]]
# multiply 2 matrix
#  [[  1  72  28]
#  [ 11 -30   1]
#  [ -7  57  14]]
# multiply 3 matrix
#  [[ 286  335]
#  [-142 -118]
#  [ 242  250]]

# %%
AM = np.array([
    [1, 2, 4],
    [7, 5, -5],
    [-2, -2, 3]
])

BM = np.array([
    [0, 2, 4],
    [1, -3, -2],
    [-2, 1, 3]
])

CM = np.array([
    [0, 3],
    [5, -4],
    [7, -1]
])

# %%
summ = np.add(AM, BM)
subst = np.subtract(AM, BM)
mult = np.dot(AM, BM)
mult_new = np.dot(mult, CM)

print( f'sum \n {summ}')
print(f'subtract \n {subst}')
print(f'multiply 2 matrix \n {mult}')
print(f'multiply 3 matrix \n {mult_new}')
# Out:
# sum
#  [[ 1  4  8]
#  [ 8  2 -7]
#  [-4 -1  6]]
# subtract
#  [[ 1  0  0]
#  [ 6  8 -3]
#  [ 0 -3  0]]
# multiply 2 matrix
#  [[-6  0 12]
#  [15 -6  3]
#  [-8  5  5]]
# multiply 3 matrix
#  [[ 84 -30]
#  [ -9  66]
#  [ 60 -49]]

# %%
AM = np.array([
    [9, 2, 4],
    [7, 5, -5],
    [6, -2, 3]
])

BM = np.array([
    [8, 2, 4],
    [0, 1, -3],
    [-2, 1, 6]
])

CM = np.array([
    [-2, 0],
    [4, 8],
    [1, -1]
])

# %%
summ = np.add(AM, BM)
subst = np.subtract(AM, BM)
mult = np.dot(AM, BM)
mult_new = np.dot(mult, CM)

print( f'sum \n {summ}')
print(f'subtract \n {subst}')
print(f'multiply 2 matrix \n {mult}')
print(f'multiply 3 matrix \n {mult_new}')
# Out:
# sum
#  [[17  4  8]
#  [ 7  6 -8]
#  [ 4 -1  9]]
# subtract
#  [[ 1  0  0]
#  [ 7  4 -2]
#  [ 8 -3 -3]]
# multiply 2 matrix
#  [[ 64  24  54]
#  [ 66  14 -17]
#  [ 42  13  48]]
# multiply 3 matrix
#  [[ 22 138]
#  [-93 129]
#  [ 16  56]]

# %% [markdown]
# Свертка фотографии

# %%
from scipy.signal import convolve2d
import matplotlib.pyplot as plt

# %%
im = plt.imread("Images/Image1.png")
im.shape
# Out:
# (2400, 1607, 3)

# %%
def plti(im, h=8, **kwargs):
    """
    Helper function to plot an image.
    """
    
    y = im.shape[0]
    x = im.shape[1]
    w = (y/x) * h
    plt.figure(figsize=(w,h))
    plt.imshow(im, interpolation="none", **kwargs)
    plt.axis('off')

plti(im)

# %% [markdown]
# Размытие по Гауссу

# %%
bw = im.mean(axis = 2)
plt.imshow(bw, cmap = 'gray')
plt.show()

# %%
#создание двухмерного Гаусового изображения

W = np.zeros((20, 20))

for i in range(20):
    for j in range(20):
        dist = (i - 9.5) ** 2 + (j - 9.5) ** 2
        W[i, j] = np.exp( -dist / 50)

plt.imshow(W, cmap= 'gray')
plt.show()

# %%
#свертка изображения

out = convolve2d(bw, W)
plt.imshow(out, cmap = 'gray')
plt.show()

# %%
out.shape
# Out:
# (2419, 1626)

# %%
#без черных краев на фотографии

out = convolve2d(bw, W, mode = 'same')
plt.imshow(out, cmap = 'gray')
plt.show()

# %%
out.shape
# Out:
# (2400, 1607)

# %% [markdown]
# Свёртки с распознаванием контура

# %%
#оператор Собеля - определяется для двух направлений с последующей аппроксимацией градиента для каждой точки изображения

Hx = np.array([
    [-1, 0, 1],
    [-2, 0, 2],
    [-1, 0, 1],
])

Hy = Hx.T

# %%
Gx = convolve2d(bw, Hx) # G - gradient, gorizont contur
plt.imshow(Gx, cmap = 'gray')
plt.show()

# %%
Gy = convolve2d(bw, Hy) #vertical contur
plt.imshow(Gx, cmap = 'gray')
plt.show()

# %%
G = np.sqrt(Gx * Gx + Gy * Gy) # находим контуры
plt.imshow(G, cmap = 'gray')
plt.show()

# %%
theta = np.arctan2(Gy, Gx) # находим направление градиентов
plt.imshow(theta, cmap = 'gray')
plt.show()

# %%
def convolve2d(image, kernel):
    """
    This function which takes an image and a kernel and returns the convolution of them.

    :param image: a numpy array of size [imageH, imageW, num_channels].
    :param kernel: a numpy array of size [kernelH, kernelW].
    :return: a convolution output.
    """

    kernelH, kernelW = kernel.shape
    imageH, imageW, num_channels = image.shape

    arr = np.zeros((imageH - kernelH + 1, imageW - kernelW + 1, num_channels)) #размер итоговой матрицы

    for channel in range(num_channels):
        for x in range(imageH - kernelH + 1):
            for y in range(imageW - kernelW + 1):
                arr[x, y, channel] = np.sum(
                                                image[x:x + kernelH, y:y + kernelW, channel] * kernel).clip(0, 255) # значения вне интервала обрезаются

    return arr.astype(np.uint8)

kernel_1 = np.array([[-1, -1, -1],
                   [-1, 9, -1],
                   [-1, -1, -1]])              

num_img = 4

fig, ax = plt.subplots(num_img, 2, figsize = (15, 15))
ax[0,0].set_title("Before")
ax[0,1].set_title("After")

for i in range(num_img):
    img = plt.imread(f"Images/Image{i+1}.jpeg")
    convolved_image1 = convolve2d(img, kernel_1)

    ax[i,0].imshow(img)
    ax[i,0].axis('off')

    ax[i,1].imshow(convolved_image1)
    ax[i,1].axis('off')

plt.show()
